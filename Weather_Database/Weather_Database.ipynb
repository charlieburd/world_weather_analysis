# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=aa60045320e0390066bc048bfaaf2e7e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taga dzong
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | caravelas
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | alexandria
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 1 | mandiana
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | taltal
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | mana
# Processing Record 26 of Set 1 | north bend
# Processing Record 27 of Set 1 | hinton
# Processing Record 28 of Set 1 | vostok
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | lasa
# Processing Record 33 of Set 1 | turukhansk
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | khuzdar
# Processing Record 36 of Set 1 | bathsheba
# Processing Record 37 of Set 1 | nombre de dios
# Processing Record 38 of Set 1 | atka
# City not found. Skipping...
# Processing Record 39 of Set 1 | cedar city
# Processing Record 40 of Set 1 | nhamunda
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | cockburn town
# Processing Record 43 of Set 1 | pontianak
# Processing Record 44 of Set 1 | pfullingen
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | prainha
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | severnoye
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | harper
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | berezovyy
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | cayenne
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 2 | brainerd
# Processing Record 12 of Set 2 | lunavada
# Processing Record 13 of Set 2 | macia
# Processing Record 14 of Set 2 | port macquarie
# Processing Record 15 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | natchez
# Processing Record 22 of Set 2 | faya
# Processing Record 23 of Set 2 | komsomolskiy
# Processing Record 24 of Set 2 | solnechnyy
# Processing Record 25 of Set 2 | horsham
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | stanghelle
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | snasa
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | hualmay
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | paita
# Processing Record 39 of Set 2 | natal
# Processing Record 40 of Set 2 | khandbari
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 2 | el tigre
# Processing Record 44 of Set 2 | rio grande
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | norfolk
# Processing Record 48 of Set 2 | sao joao dos patos
# Processing Record 49 of Set 2 | zaraza
# Processing Record 50 of Set 2 | zeya
# Processing Record 1 of Set 3 | basoko
# Processing Record 2 of Set 3 | cervo
# Processing Record 3 of Set 3 | rawson
# Processing Record 4 of Set 3 | hengshui
# Processing Record 5 of Set 3 | hami
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | pokosnoye
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | willowmore
# Processing Record 10 of Set 3 | saint anthony
# Processing Record 11 of Set 3 | trincomalee
# Processing Record 12 of Set 3 | coffs harbour
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | yulara
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | orel-izumrud
# Processing Record 21 of Set 3 | weligama
# Processing Record 22 of Set 3 | partizanskoye
# Processing Record 23 of Set 3 | hovd
# Processing Record 24 of Set 3 | hay river
# Processing Record 25 of Set 3 | juegang
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | mao
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | santa rita do sapucai
# Processing Record 33 of Set 3 | puerto colombia
# Processing Record 34 of Set 3 | asgabat
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | cairns
# Processing Record 37 of Set 3 | komsomolets
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | antigonish
# Processing Record 43 of Set 3 | fairbanks
# Processing Record 44 of Set 3 | samarai
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | santa lucia
# Processing Record 47 of Set 3 | aksu
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | bumba
# Processing Record 1 of Set 4 | bjornevatn
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | rakaia
# Processing Record 4 of Set 4 | wageningen
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | grand-santi
# Processing Record 8 of Set 4 | shimoda
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | weihe
# Processing Record 11 of Set 4 | itoman
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | lanzhou
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 4 | meulaboh
# Processing Record 21 of Set 4 | ola
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | tautira
# Processing Record 24 of Set 4 | hobart
# Processing Record 25 of Set 4 | janow lubelski
# Processing Record 26 of Set 4 | kirensk
# Processing Record 27 of Set 4 | flinders
# Processing Record 28 of Set 4 | sept-iles
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | ramkola
# Processing Record 31 of Set 4 | alpena
# Processing Record 32 of Set 4 | clearlake
# Processing Record 33 of Set 4 | hervey bay
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | saint-georges
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | sarangani
# Processing Record 38 of Set 4 | lahaina
# Processing Record 39 of Set 4 | the pas
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | la reforma
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | qarqin
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | nushki
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 4 | cambara
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | torrelavega
# Processing Record 1 of Set 5 | villaviciosa
# Processing Record 2 of Set 5 | cabra
# Processing Record 3 of Set 5 | bafra
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | correntina
# Processing Record 6 of Set 5 | high level
# Processing Record 7 of Set 5 | chokurdakh
# Processing Record 8 of Set 5 | phan thiet
# Processing Record 9 of Set 5 | fort nelson
# Processing Record 10 of Set 5 | norman wells
# Processing Record 11 of Set 5 | moratuwa
# Processing Record 12 of Set 5 | aksarka
# Processing Record 13 of Set 5 | tiarei
# Processing Record 14 of Set 5 | corinto
# Processing Record 15 of Set 5 | chapleau
# Processing Record 16 of Set 5 | esperance
# Processing Record 17 of Set 5 | nenjiang
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | sungairaya
# Processing Record 20 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 5 | tuktoyaktuk
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | vulcan
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | veraval
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | aswan
# Processing Record 29 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 5 | burnie
# Processing Record 31 of Set 5 | broome
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | pimentel
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | haines junction
# Processing Record 36 of Set 5 | beihai
# Processing Record 37 of Set 5 | lerwick
# Processing Record 38 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 5 | buin
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | novyy urengoy
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | ilo
# Processing Record 44 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 5 | mwinilunga
# Processing Record 46 of Set 5 | saint-francois
# Processing Record 47 of Set 5 | abha
# Processing Record 48 of Set 5 | saint-louis
# Processing Record 49 of Set 5 | jibuti
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | strezhevoy
# Processing Record 2 of Set 6 | houma
# Processing Record 3 of Set 6 | concepcion
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | wonthaggi
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | atuona
# Processing Record 9 of Set 6 | majene
# Processing Record 10 of Set 6 | riyadh
# Processing Record 11 of Set 6 | kirkwall
# Processing Record 12 of Set 6 | chama
# Processing Record 13 of Set 6 | mahebourg
# Processing Record 14 of Set 6 | asyut
# Processing Record 15 of Set 6 | antofagasta
# Processing Record 16 of Set 6 | tonosho
# Processing Record 17 of Set 6 | lebu
# Processing Record 18 of Set 6 | celestun
# Processing Record 19 of Set 6 | baley
# Processing Record 20 of Set 6 | ust-kuyga
# Processing Record 21 of Set 6 | pathein
# Processing Record 22 of Set 6 | samana
# Processing Record 23 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | gizo
# Processing Record 26 of Set 6 | buala
# Processing Record 27 of Set 6 | san javier
# Processing Record 28 of Set 6 | lokosovo
# Processing Record 29 of Set 6 | kenora
# Processing Record 30 of Set 6 | tessalit
# Processing Record 31 of Set 6 | takoradi
# Processing Record 32 of Set 6 | asfi
# Processing Record 33 of Set 6 | staryy saltiv
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | nacala
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | vengerovo
# Processing Record 38 of Set 6 | malanje
# Processing Record 39 of Set 6 | dicabisagan
# Processing Record 40 of Set 6 | lata
# Processing Record 41 of Set 6 | rudnyy
# Processing Record 42 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 6 | lovozero
# Processing Record 44 of Set 6 | grand-lahou
# Processing Record 45 of Set 6 | poum
# Processing Record 46 of Set 6 | san cristobal
# Processing Record 47 of Set 6 | svarstad
# Processing Record 48 of Set 6 | coihaique
# Processing Record 49 of Set 6 | nouadhibou
# Processing Record 50 of Set 6 | mananara
# Processing Record 1 of Set 7 | college
# Processing Record 2 of Set 7 | richards bay
# Processing Record 3 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | pauini
# Processing Record 5 of Set 7 | bilma
# Processing Record 6 of Set 7 | sokol
# Processing Record 7 of Set 7 | brae
# Processing Record 8 of Set 7 | kloulklubed
# Processing Record 9 of Set 7 | russell
# Processing Record 10 of Set 7 | aitape
# Processing Record 11 of Set 7 | manyana
# Processing Record 12 of Set 7 | saravan
# Processing Record 13 of Set 7 | whangamata
# Processing Record 14 of Set 7 | bambanglipuro
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | necochea
# Processing Record 17 of Set 7 | rocha
# Processing Record 18 of Set 7 | vestmanna
# Processing Record 19 of Set 7 | whitefish
# Processing Record 20 of Set 7 | lamu
# Processing Record 21 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 7 | shingu
# Processing Record 23 of Set 7 | ust-tsilma
# Processing Record 24 of Set 7 | benton
# Processing Record 25 of Set 7 | dehloran
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | baykit
# Processing Record 28 of Set 7 | masallatah
# Processing Record 29 of Set 7 | gushikawa
# Processing Record 30 of Set 7 | ribeira brava
# Processing Record 31 of Set 7 | jijiga
# Processing Record 32 of Set 7 | moussoro
# Processing Record 33 of Set 7 | barstow
# Processing Record 34 of Set 7 | harnoli
# Processing Record 35 of Set 7 | chumikan
# Processing Record 36 of Set 7 | galveston
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | sibolga
# Processing Record 39 of Set 7 | acapulco
# Processing Record 40 of Set 7 | sao gabriel da cachoeira
# Processing Record 41 of Set 7 | tonkino
# Processing Record 42 of Set 7 | matagami
# Processing Record 43 of Set 7 | brigantine
# Processing Record 44 of Set 7 | semey
# Processing Record 45 of Set 7 | chimoio
# Processing Record 46 of Set 7 | camacha
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | olafsvik
# Processing Record 49 of Set 7 | kirakira
# Processing Record 50 of Set 7 | vardo
# Processing Record 1 of Set 8 | locri
# Processing Record 2 of Set 8 | akdepe
# Processing Record 3 of Set 8 | ayan
# Processing Record 4 of Set 8 | nishihara
# Processing Record 5 of Set 8 | xining
# Processing Record 6 of Set 8 | kato milea
# Processing Record 7 of Set 8 | sabirabad
# Processing Record 8 of Set 8 | bubaque
# Processing Record 9 of Set 8 | parana
# Processing Record 10 of Set 8 | ugoofaaru
# Processing Record 11 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 8 | bay roberts
# Processing Record 13 of Set 8 | upata
# Processing Record 14 of Set 8 | rafaela
# Processing Record 15 of Set 8 | port elizabeth
# Processing Record 16 of Set 8 | agar
# Processing Record 17 of Set 8 | gamba
# Processing Record 18 of Set 8 | umm lajj
# Processing Record 19 of Set 8 | maneadero
# Processing Record 20 of Set 8 | mareeba
# Processing Record 21 of Set 8 | mulchen
# Processing Record 22 of Set 8 | cerqueira cesar
# Processing Record 23 of Set 8 | najran
# Processing Record 24 of Set 8 | salalah
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | dakar
# Processing Record 27 of Set 8 | kapit
# Processing Record 28 of Set 8 | copiapo
# Processing Record 29 of Set 8 | comodoro rivadavia
# Processing Record 30 of Set 8 | pekalongan
# Processing Record 31 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 32 of Set 8 | port pirie
# Processing Record 33 of Set 8 | putina
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | visnes
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | tezu
# Processing Record 38 of Set 8 | nandi hills
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | ostrovnoy
# Processing Record 41 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 8 | roald
# Processing Record 43 of Set 8 | cacoal
# Processing Record 44 of Set 8 | tual
# Processing Record 45 of Set 8 | agadez
# Processing Record 46 of Set 8 | kuusamo
# Processing Record 47 of Set 8 | moyale
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | sao joao da barra
# Processing Record 50 of Set 8 | simao
# Processing Record 1 of Set 9 | adrar
# Processing Record 2 of Set 9 | bollnas
# Processing Record 3 of Set 9 | cherskiy
# Processing Record 4 of Set 9 | puerto escondido
# Processing Record 5 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 9 | lubbock
# Processing Record 7 of Set 9 | champerico
# Processing Record 8 of Set 9 | guiren
# Processing Record 9 of Set 9 | gewane
# Processing Record 10 of Set 9 | los llanos de aridane
# Processing Record 11 of Set 9 | price
# Processing Record 12 of Set 9 | acurenam
# Processing Record 13 of Set 9 | kysyl-syr
# Processing Record 14 of Set 9 | antalaha
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 17 of Set 9 | khorixas
# Processing Record 18 of Set 9 | mudon
# Processing Record 19 of Set 9 | zdvinsk
# Processing Record 20 of Set 9 | tessaoua
# Processing Record 21 of Set 9 | blackwater
# Processing Record 22 of Set 9 | norsup
# Processing Record 23 of Set 9 | krasnoborsk
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | majalgaon
# Processing Record 26 of Set 9 | shubarkuduk
# Processing Record 27 of Set 9 | mount isa
# Processing Record 28 of Set 9 | kilindoni
# Processing Record 29 of Set 9 | bend
# Processing Record 30 of Set 9 | tchollire
# Processing Record 31 of Set 9 | pontes e lacerda
# Processing Record 32 of Set 9 | daru
# Processing Record 33 of Set 9 | tura
# Processing Record 34 of Set 9 | mbuji-mayi
# Processing Record 35 of Set 9 | saint-pierre
# Processing Record 36 of Set 9 | yaroslavskiy
# Processing Record 37 of Set 9 | kalavad
# Processing Record 38 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 9 | lazaro cardenas
# Processing Record 40 of Set 9 | kutum
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | kurilsk
# Processing Record 43 of Set 9 | gayeri
# Processing Record 44 of Set 9 | mandalgovi
# Processing Record 45 of Set 9 | kampene
# Processing Record 46 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 9 | tabou
# Processing Record 48 of Set 9 | dwarka
# Processing Record 49 of Set 9 | batagay
# Processing Record 50 of Set 9 | kirksville
# Processing Record 1 of Set 10 | skibbereen
# Processing Record 2 of Set 10 | uppsala
# Processing Record 3 of Set 10 | huicungo
# Processing Record 4 of Set 10 | vamvakou
# Processing Record 5 of Set 10 | ust-barguzin
# Processing Record 6 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 10 | beringovskiy
# Processing Record 8 of Set 10 | parabel
# Processing Record 9 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 10 of Set 10 | davenda
# Processing Record 11 of Set 10 | liberal
# Processing Record 12 of Set 10 | shellbrook
# Processing Record 13 of Set 10 | husavik
# Processing Record 14 of Set 10 | biltine
# Processing Record 15 of Set 10 | sirawai
# Processing Record 16 of Set 10 | ibra
# Processing Record 17 of Set 10 | kudahuvadhoo
# Processing Record 18 of Set 10 | la rioja
# Processing Record 19 of Set 10 | sayyan
# Processing Record 20 of Set 10 | honningsvag
# Processing Record 21 of Set 10 | srednekolymsk
# Processing Record 22 of Set 10 | poso
# Processing Record 23 of Set 10 | zonguldak
# Processing Record 24 of Set 10 | along
# Processing Record 25 of Set 10 | cavalcante
# Processing Record 26 of Set 10 | waw
# Processing Record 27 of Set 10 | port augusta
# Processing Record 28 of Set 10 | siutu
# City not found. Skipping...
# Processing Record 29 of Set 10 | atkinson
# Processing Record 30 of Set 10 | aykhal
# Processing Record 31 of Set 10 | kitgum
# Processing Record 32 of Set 10 | ulaangom
# Processing Record 33 of Set 10 | bethanien
# Processing Record 34 of Set 10 | ranong
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | kasongo-lunda
# Processing Record 37 of Set 10 | lichinga
# Processing Record 38 of Set 10 | quelimane
# Processing Record 39 of Set 10 | ossora
# Processing Record 40 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of Set 10 | yerbogachen
# Processing Record 42 of Set 10 | grindavik
# Processing Record 43 of Set 10 | akure
# Processing Record 44 of Set 10 | havoysund
# Processing Record 45 of Set 10 | ulladulla
# Processing Record 46 of Set 10 | talaya
# Processing Record 47 of Set 10 | sinnamary
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | barras
# Processing Record 50 of Set 10 | hobyo
# Processing Record 1 of Set 11 | hermiston
# Processing Record 2 of Set 11 | ixtapa
# Processing Record 3 of Set 11 | fecamp
# Processing Record 4 of Set 11 | codrington
# Processing Record 5 of Set 11 | bow island
# Processing Record 6 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao paulo de olivenca
# Processing Record 8 of Set 11 | dingle
# Processing Record 9 of Set 11 | nemuro
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | micheweni
# Processing Record 12 of Set 11 | barrhead
# Processing Record 13 of Set 11 | shache
# Processing Record 14 of Set 11 | yeniseysk
# Processing Record 15 of Set 11 | parsabad
# Processing Record 16 of Set 11 | pitsunda
# Processing Record 17 of Set 11 | tsabong
# Processing Record 18 of Set 11 | maputo
# Processing Record 19 of Set 11 | lakes entrance
# Processing Record 20 of Set 11 | sulphur
# Processing Record 21 of Set 11 | pastavy
# Processing Record 22 of Set 11 | nelson bay
# Processing Record 23 of Set 11 | talnakh
# Processing Record 24 of Set 11 | atoyac
# Processing Record 25 of Set 11 | wajid
# Processing Record 26 of Set 11 | rio tuba
# Processing Record 27 of Set 11 | osa
# Processing Record 28 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 11 | motherwell
# Processing Record 30 of Set 11 | vondrozo
# Processing Record 31 of Set 11 | lac du bonnet
# Processing Record 32 of Set 11 | los alamos
# Processing Record 33 of Set 11 | gigmoto
# Processing Record 34 of Set 11 | ongwediva
# Processing Record 35 of Set 11 | katsuura
# Processing Record 36 of Set 11 | tateyama
# Processing Record 37 of Set 11 | dunedin
# Processing Record 38 of Set 11 | rokupr
# Processing Record 39 of Set 11 | san-pedro
# Processing Record 40 of Set 11 | san quintin
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | fortuna
# Processing Record 43 of Set 11 | labuan
# Processing Record 44 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 11 | ekibastuz
# Processing Record 46 of Set 11 | san ignacio
# Processing Record 47 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 11 | miandrivazo
# Processing Record 49 of Set 11 | arlit
# Processing Record 50 of Set 11 | lishui
# Processing Record 1 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | little current
# Processing Record 4 of Set 12 | mackay
# Processing Record 5 of Set 12 | dzilam gonzalez
# Processing Record 6 of Set 12 | porvoo
# Processing Record 7 of Set 12 | rio gallegos
# Processing Record 8 of Set 12 | megion
# Processing Record 9 of Set 12 | gunjur
# Processing Record 10 of Set 12 | neyshabur
# Processing Record 11 of Set 12 | governador dix-sept rosado
# Processing Record 12 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 13 of Set 12 | tutoia
# Processing Record 14 of Set 12 | korla
# Processing Record 15 of Set 12 | roswell
# Processing Record 16 of Set 12 | zyryanka
# Processing Record 17 of Set 12 | puerto del rosario
# Processing Record 18 of Set 12 | peachland
# Processing Record 19 of Set 12 | canton
# Processing Record 20 of Set 12 | mamit
# Processing Record 21 of Set 12 | bealanana
# Processing Record 22 of Set 12 | khash
# Processing Record 23 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 12 | bakchar
# Processing Record 25 of Set 12 | odweyne
# Processing Record 26 of Set 12 | kahului
# Processing Record 27 of Set 12 | oksbol
# Processing Record 28 of Set 12 | touros
# Processing Record 29 of Set 12 | havre-saint-pierre
# Processing Record 30 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 12 | fengcheng
# Processing Record 32 of Set 12 | ust-koksa
# Processing Record 33 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 12 | udachnyy
# Processing Record 35 of Set 12 | butte
# Processing Record 36 of Set 12 | port hardy
# Processing Record 37 of Set 12 | voznesenskoye
# Processing Record 38 of Set 12 | manoel urbano
# Processing Record 39 of Set 12 | chifeng
# Processing Record 40 of Set 12 | havelock
# Processing Record 41 of Set 12 | sola
# Processing Record 42 of Set 12 | ilhabela
# Processing Record 43 of Set 12 | north platte
# Processing Record 44 of Set 12 | bonavista
# Processing Record 45 of Set 12 | conakry
# Processing Record 46 of Set 12 | beloha
# Processing Record 47 of Set 12 | lagunas
# Processing Record 48 of Set 12 | pafos
# Processing Record 49 of Set 12 | makung
# City not found. Skipping...
# Processing Record 50 of Set 12 | frankfort
# Processing Record 1 of Set 13 | zhangjiakou
# Processing Record 2 of Set 13 | peace river
# Processing Record 3 of Set 13 | yumen
# Processing Record 4 of Set 13 | athabasca
# Processing Record 5 of Set 13 | quatre cocos
# Processing Record 6 of Set 13 | yangambi
# Processing Record 7 of Set 13 | murillo
# Processing Record 8 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 13 | saint-augustin
# Processing Record 10 of Set 13 | fort-shevchenko
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | himora
# City not found. Skipping...
# Processing Record 13 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 13 | takob
# City not found. Skipping...
# Processing Record 15 of Set 13 | vilyuysk
# Processing Record 16 of Set 13 | kulhudhuffushi
# Processing Record 17 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 18 of Set 13 | namibe
# Processing Record 19 of Set 13 | dunmore town
# Processing Record 20 of Set 13 | waddan
# Processing Record 21 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 13 | nouakchott
# Processing Record 23 of Set 13 | eyrarbakki
# Processing Record 24 of Set 13 | wattegama
# Processing Record 25 of Set 13 | san rafael
# Processing Record 26 of Set 13 | talara
# Processing Record 27 of Set 13 | ayr
# Processing Record 28 of Set 13 | aykino
# Processing Record 29 of Set 13 | foshan
# Processing Record 30 of Set 13 | henties bay
# Processing Record 31 of Set 13 | kalabo
# Processing Record 32 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 13 | lagoa
# Processing Record 34 of Set 13 | batagay-alyta
# Processing Record 35 of Set 13 | zaria
# Processing Record 36 of Set 13 | ciuhoiu
# Processing Record 37 of Set 13 | san rafael del sur
# Processing Record 38 of Set 13 | coquimbo
# Processing Record 39 of Set 13 | tooele
# Processing Record 40 of Set 13 | usinsk
# Processing Record 41 of Set 13 | gazojak
# Processing Record 42 of Set 13 | azul
# Processing Record 43 of Set 13 | guerande
# Processing Record 44 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 45 of Set 13 | suez
# Processing Record 46 of Set 13 | santiago del estero
# Processing Record 47 of Set 13 | half moon bay
# Processing Record 48 of Set 13 | tazovskiy
# Processing Record 49 of Set 13 | mokhsogollokh
# Processing Record 50 of Set 13 | valvedditturai
# Processing Record 1 of Set 14 | nagaur
# Processing Record 2 of Set 14 | ialibu
# Processing Record 3 of Set 14 | derzhavinsk
# Processing Record 4 of Set 14 | kenai
# Processing Record 5 of Set 14 | kumla
# Processing Record 6 of Set 14 | panguna
# Processing Record 7 of Set 14 | am timan
# Processing Record 8 of Set 14 | palana
# Processing Record 9 of Set 14 | calabozo
# Processing Record 10 of Set 14 | tshikapa
# Processing Record 11 of Set 14 | kapuskasing
# Processing Record 12 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 14 | ostersund
# Processing Record 14 of Set 14 | mahibadhoo
# Processing Record 15 of Set 14 | okahandja
# Processing Record 16 of Set 14 | bucerias
# Processing Record 17 of Set 14 | talcahuano
# Processing Record 18 of Set 14 | wahiawa
# Processing Record 19 of Set 14 | ucluelet
# Processing Record 20 of Set 14 | drumnadrochit
# Processing Record 21 of Set 14 | bongandanga
# Processing Record 22 of Set 14 | malabo
# Processing Record 23 of Set 14 | la palma
# Processing Record 24 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 14 | ca mau
# Processing Record 26 of Set 14 | tainan
# Processing Record 27 of Set 14 | george
# Processing Record 28 of Set 14 | yeppoon
# Processing Record 29 of Set 14 | kabare
# Processing Record 30 of Set 14 | tlacote el bajo
# Processing Record 31 of Set 14 | manavalakurichi
# Processing Record 32 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 14 | bereznik
# Processing Record 34 of Set 14 | gurupi
# Processing Record 35 of Set 14 | lazi
# Processing Record 36 of Set 14 | gerash
# Processing Record 37 of Set 14 | wabana
# Processing Record 38 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 14 | blagnac
# Processing Record 40 of Set 14 | cortez
# Processing Record 41 of Set 14 | tuy hoa
# Processing Record 42 of Set 14 | esil
# Processing Record 43 of Set 14 | bambui
# Processing Record 44 of Set 14 | namatanai
# Processing Record 45 of Set 14 | issenye
# Processing Record 46 of Set 14 | mandal
# Processing Record 47 of Set 14 | huarmey
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | diffa
# Processing Record 50 of Set 14 | suhut
# Processing Record 1 of Set 15 | neuquen
# Processing Record 2 of Set 15 | tomatlan
# Processing Record 3 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 15 | nianzishan
# Processing Record 5 of Set 15 | salta
# Processing Record 6 of Set 15 | takhtamygda
# Processing Record 7 of Set 15 | jaca
# Processing Record 8 of Set 15 | aakirkeby
# City not found. Skipping...
# Processing Record 9 of Set 15 | chauk
# Processing Record 10 of Set 15 | atasu
# Processing Record 11 of Set 15 | molochnoye
# Processing Record 12 of Set 15 | mogadishu
# Processing Record 13 of Set 15 | matata
# Processing Record 14 of Set 15 | bayonet point
# Processing Record 15 of Set 15 | sarahan
# Processing Record 16 of Set 15 | braganca
# Processing Record 17 of Set 15 | eydhafushi
# Processing Record 18 of Set 15 | maniitsoq
# Processing Record 19 of Set 15 | la asuncion
# Processing Record 20 of Set 15 | ndola
# Processing Record 21 of Set 15 | mino
# Processing Record 22 of Set 15 | cap-aux-meules
# Processing Record 23 of Set 15 | vallenar
# Processing Record 24 of Set 15 | kikwit
# Processing Record 25 of Set 15 | jacareacanga
# Processing Record 26 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 15 | katangli
# Processing Record 28 of Set 15 | springbok
# Processing Record 29 of Set 15 | leningradskiy
# Processing Record 30 of Set 15 | zaraysk
# Processing Record 31 of Set 15 | charters towers
# Processing Record 32 of Set 15 | elat
# Processing Record 33 of Set 15 | xiongzhou
# Processing Record 34 of Set 15 | nome
# Processing Record 35 of Set 15 | pangody
# Processing Record 36 of Set 15 | iquitos
# Processing Record 37 of Set 15 | griffith
# Processing Record 38 of Set 15 | ingham
# Processing Record 39 of Set 15 | lashio
# Processing Record 40 of Set 15 | serafimovich
# Processing Record 41 of Set 15 | coos bay
# Processing Record 42 of Set 15 | koslan
# Processing Record 43 of Set 15 | verkhnyaya inta
# Processing Record 44 of Set 15 | baghdad
# Processing Record 45 of Set 15 | burica
# City not found. Skipping...
# Processing Record 46 of Set 15 | panama city
# Processing Record 47 of Set 15 | thames
# Processing Record 48 of Set 15 | mount pleasant
# Processing Record 49 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 15 | taupo
# Processing Record 1 of Set 16 | lesnoye
# Processing Record 2 of Set 16 | stornoway
# Processing Record 3 of Set 16 | abastumani
# Processing Record 4 of Set 16 | ouadda
# Processing Record 5 of Set 16 | tangier
# Processing Record 6 of Set 16 | muli
# Processing Record 7 of Set 16 | mizdah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.tail(10)
# Out:
#                City    Lat     Lng  Max Temp Current Description  Humidity  \
# 679          Thames -37.13  175.53     73.00          light rain        58
# 680  Mount Pleasant  32.79  -79.86     66.00           clear sky        88
# 681           Taupo -38.68  176.08     69.01     overcast clouds        71
# 682         Lesnoye  58.28   35.52     34.23     overcast clouds        89
# 683       Stornoway  58.21   -6.39     46.99    scattered clouds        93
# 684      Abastumani  41.71   42.85     59.00     overcast clouds        87
# 685          Ouadda   8.08   22.40     67.98     overcast clouds        87
# 686         Tangier  35.78   -5.81     62.60           clear sky        72
# 687            Muli   2.92   73.57     82.20          few clouds        71
# 688          Mizdah  31.45   12.98     55.35           clear sky        80
#
#      Cloudiness  Wind Speed Country
# 679         100        5.01      NZ
# 680           1        5.82      US
# 681         100        7.00      NZ
# 682         100        5.35      RU
# 683          39       19.46      GB
# 684          90       13.87      GE
# 685          87        1.10      CF
# 686           0       10.29      MA
# 687          20        5.28      MV
# 688           0        5.59      LY

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0             Cape Town      ZA -33.93   18.42     64.40        72
# 1               Rikitea      PF -23.12 -134.97     74.16        85
# 2                Dikson      RU  73.51   80.55     18.09        98
# 3  Vila Franca Do Campo      PT  37.72  -25.43     62.60        88
# 4           Clyde River      CA  70.47  -68.59     10.40        85
# 5             Caravelas      BR -17.71  -39.25     71.78        84
# 6             Busselton      AU -33.65  115.33     61.00        87
# 7          Ponta Do Sol      PT  32.67  -17.10     68.00        88
# 8            Alexandria      EG  31.22   29.96     71.60        60
# 9           New Norfolk      AU -42.78  147.06     72.00        36
#
#    Cloudiness  Wind Speed Current Description
# 0           0       13.87           clear sky
# 1          93       23.53     overcast clouds
# 2          97        8.30     overcast clouds
# 3          75       16.11       broken clouds
# 4           1        6.93           clear sky
# 5         100       10.54          light rain
# 6         100        5.91     overcast clouds
# 7          75        4.70       broken clouds
# 8          40       10.29    scattered clouds
# 9          99        3.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
